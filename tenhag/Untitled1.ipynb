# %%
import pandas as pd

# %%
df = pd.read_csv("./중고차데이터최종v8.csv", encoding="cp949")

# %%
df
# Out:
#        Unnamed: 0  index                                    이름  제조회사   모델명  \
# 0               0      0                 쌍용 티볼리 LX 2WD 세부등급 없음    쌍용   티볼리
# 1               1      1                         기아 올 뉴 모닝 럭셔리    기아    모닝
# 2               2      2               쉐보레(GM대우) 알페온 EL300 슈프림   쉐보레   알페온
# 3               3      3            쌍용 렉스턴 스포츠 디젤 2.2 4WD 노블레스    쌍용   렉스턴
# 4               4      4  쉐보레(GM대우) 더 뉴 말리부 1.3 터보 프리미어 세부등급없음   쉐보레   말리부
# ...           ...    ...                                   ...   ...   ...
# 14552       14552  14552                                아우디 S4   아우디    S4
# 14553       14553  14553                              기아 스포티지R    기아  스포티지
# 14554       14554  14554                         폭스바겐 티구안(1세대)  폭스바겐   티구안
# 14555       14555  14555                            제네시스 EQ900  제네시스  제네시스
# 14556       14556  14556                            현대 에쿠스(신형)    현대   에쿠스
#
# ...

# %%
df_model = df.groupby('세부모델').mean()

# %%
df_model.to_csv("./model.csv")

# %%
pd.read_csv("./model.csv")
# Out:
#                   세부모델    Unnamed: 0         index            가격      배기량  \
# 0                  124  11133.000000  11133.000000   3580.000000  1356.00
# 1    1시리즈 2세대 (12~19년)   9270.208333   9270.208333   1538.041667  1995.00
# 2    1시리즈 3세대 (20년~현재)   3936.400000   3936.400000   3786.000000  1997.40
# 3                 2008  10965.461538  10965.461538   1003.923077  1560.00
# 4                  207   6838.500000   6838.500000    547.250000  1598.00
# ..                 ...           ...           ...           ...      ...
# 621               프리우스  12277.500000  12277.500000   1375.000000  1647.50
# 622           프리우스 4세대   4053.000000   4053.000000   2347.500000  1722.75
# 623          플라잉스퍼 1세대  12536.000000  12536.000000   4650.000000  6000.00
# 624          플라잉스퍼 2세대  11251.000000  11251.000000  12150.000000  3993.00
# 625                휘가로  11155.000000  11155.000000   2500.000000  1000.00
#
#               연식           주행거리  압류/저당      사고유무  전손이력     신차가격  감가상각률  \
# ...

# %%
df['제조회사'].value_counts().index
# Out:
# Index(['현대', '기아', '쉐보레', '르노삼성', '쌍용', '제네시스', 'BMW', '벤츠', '아우디', '폭스바겐',
#        '미니', '지프', '포드', '볼보', '랜드로버', '푸조', '재규어', '렉서스', '링컨', '인피니티', '혼다',
#        '도요타', '포르쉐', '닛산', '캐딜락', '대형트럭(2톤이상)', '마세라티', '시트로엥', '토요타', '크라이슬러',
#        '피아트', '대형버스(16인승이상)', '테슬라', '닷지', '미쯔비시', '북기은상', '스마트', '벤틀리',
#        '애스턴마틴', '롤스로이스', '선롱', '람보르기니', '험머'],
#       dtype='object')
